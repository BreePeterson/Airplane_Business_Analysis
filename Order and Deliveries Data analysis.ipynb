# %%
import pandas as pd

# %%
ordAndDel = pd.read_csv('OrdersandDeliveries.csv')

# %%
ordAndDel.head()
# Out:
#        Country           Customer Name Delivery Year  Engine Model Series  \
# 0  Afghanistan  Ariana Afghan Airlines           1968     PW          727
# 1  Afghanistan  Ariana Afghan Airlines           1970     PW          727
# 2  Afghanistan  Ariana Afghan Airlines           1979     GE        DC-10
# 3  Afghanistan  Ariana Afghan Airlines            NaN     CF      737-700
# 4      Algeria             Air Algerie           1974     PW          727
#
#   Order Month Order Year        Region Delivery Total Order Total  \
# 0         Mar       1968  Central Asia              1           1
# 1         Apr       1969  Central Asia              1           1
# 2         Sep       1978  Central Asia              1           1
# 3         Nov       2005  Central Asia              0           4
# 4         Jan       1974        Africa              1           1
#
#   Unfilled Orders
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
ordAndDel.tail()
# Out:
#        Country Customer Name Delivery Year  Engine Model Series Order Month  \
# 9068  Zimbabwe  Air Zimbabwe           1987     PW      737-200         Jan
# 9069  Zimbabwe  Air Zimbabwe           1990     PW    767-200ER         Mar
# 9070  Zimbabwe  Air Zimbabwe           1989     PW    767-200ER         Jul
# 9071  Zimbabwe  Air Zimbabwe           1986     PW      737-200         Dec
# 9072       All           All            All    All          All         All
#
#      Order Year  Region Delivery Total Order Total Unfilled Orders
# 9068       1987  Africa              2           2             NaN
# 9069       1989  Africa              1           1             NaN
# 9070       1988  Africa              1           1             NaN
# 9071       1986  Africa              1           1             NaN
# 9072        All     All         24,025      33,587           5,163
